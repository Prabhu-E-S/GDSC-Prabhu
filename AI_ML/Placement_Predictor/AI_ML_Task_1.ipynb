# %%
# import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# reading the file
dataset = pd.read_csv('Placement_BeginnerTask01 (1).csv')
dataset.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# ...

# %%
# dropping StudentID column
dataset = dataset.drop('StudentID', axis=1)

# %%
# categorising columns for further labelling
dataset["ExtracurricularActivities"] = dataset["ExtracurricularActivities"].astype('category')
dataset["PlacementTraining"] = dataset["PlacementTraining"].astype('category')
dataset["PlacementStatus"] = dataset["PlacementStatus"].astype('category')

dataset.dtypes
# Out:
# CGPA                          float64
# Internships                     int64
# Projects                        int64
# Workshops/Certifications        int64
# AptitudeTestScore               int64
# SoftSkillsRating              float64
# ExtracurricularActivities    category
# PlacementTraining            category
# SSC_Marks                       int64
# HSC_Marks                       int64
# PlacementStatus              category
# dtype: object

# %%
# labelling the columns
dataset["ExtracurricularActivities"] = dataset["ExtracurricularActivities"].cat.codes
dataset["PlacementTraining"] = dataset["PlacementTraining"].cat.codes
dataset["PlacementStatus"] = dataset["PlacementStatus"].cat.codes

# display dataset
dataset.head()
# Out:
#    CGPA  Internships  Projects  Workshops/Certifications  AptitudeTestScore  \
# 0   7.5            1         1                         1                 65
# 1   8.9            0         3                         2                 90
# 2   7.3            1         2                         2                 82
# 3   7.5            1         1                         2                 85
# 4   8.3            1         2                         2                 86
#
#    SoftSkillsRating  ExtracurricularActivities  PlacementTraining  SSC_Marks  \
# 0               4.4                          0                  0         61
# 1               4.0                          1                  1         78
# 2               4.8                          1                  0         79
# 3               4.4                          1                  1         81
# 4               4.5                          1                  1         74
#
#    HSC_Marks  PlacementStatus
# ...

# %%
# selecting the features and labels
X = dataset[['CGPA',
             'Internships',
             'Projects',
             'Workshops/Certifications',
             'AptitudeTestScore',
             'SoftSkillsRating',
             'ExtracurricularActivities',
             'PlacementTraining',
             'SSC_Marks',
             'HSC_Marks']]

Y = dataset['PlacementStatus']
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    1
# 9997    1
# 9998    1
# 9999    0
# Name: PlacementStatus, Length: 10000, dtype: int8

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_pred = clf.predict(X_test)
Y_pred
# Out:
# array([0, 0, 0, ..., 1, 1, 0], dtype=int8)

# %%
# printing the accuracy
clf.score(X_test, Y_test)
# Out:
# 0.7945

# %%
#Confusion Matrix and Accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score

print(confusion_matrix(Y_test, Y_pred))
print("Accuracy:", accuracy_score(Y_test, Y_pred))
# Out:
# [[954 218]
#  [193 635]]
# Accuracy: 0.7945

# %%
def placement_message(model, student_data):
    prob = model.predict_proba(student_data)[0][1]  # probability of being placed

    if prob >= 0.75:
        print(f"You have a HIGH chance of getting placed ({prob*100:.2f}%)")
    elif prob >= 0.5:
        print(f"You have a MODERATE chance of getting placed ({prob*100:.2f}%)")
    else:
        print(f"You have a LOW chance of getting placed ({prob*100:.2f}%)")

# %%
#[[9.6, 2, 3, 4, 78, 8.5, 1, 1, 85, 88]] high chance
#[[7.4, 1, 1, 2, 70, 7.5, 1, 0, 75, 78]] moderate chance
#[[3.4, 0, 1, 0, 40, 4.5, 0, 0, 55, 58]] low chance

# %%
data=eval(input("Enter the Data of the student in the format [CGPA,Internships,Projects,Workshops,AptitudeTestScore,SoftskillRating,ExtracurricularActivies,PlacementTraining,SSC_Marks,HSC_Marks]"))
# Out:
# Enter the Data of the student in the format [CGPA,Internships,Projects,Workshops,AptitudeTestScore,SoftskillRating,ExtracurricularActivies,PlacementTraining,SSC_Marks,HSC_Marks][[9.6, 2, 3, 4, 78, 8.5, 1, 1, 85, 88]]

# %%
placement_message(clf, data)
# Out:
# You have a HIGH chance of getting placed (99.44%)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
